# %%
import pandas as pd

# %%
df=pd.read_csv('train.csv')
df.head()
# Out:
#                         _id  subscription_length  vehicle_age  customer_age  \
# 0  67fa515ada8b776abac2c0aa                  0.5          2.2            39
# 1  67fa515bda8b776abac323cb                 11.6          2.4            57
# 2  67fa515bda8b776abac31505                  2.6          2.6            50
# 3  67fa515bda8b776abac33bda                  1.8          1.4            35
# 4  67fa515ada8b776abac2a74c                  0.3          0.2            56
#
#   region_code  region_density segment model fuel_type      max_torque  ...  \
# 0          C2           27003      B1    M8       CNG  82.1Nm@3400rpm  ...
# 1          C8            8794      B1    M8       CNG  82.1Nm@3400rpm  ...
# 2          C8            8794      B2    M6    Petrol   113Nm@4400rpm  ...
# 3         C14            7788      C2    M4    Diesel   250Nm@2750rpm  ...
# 4          C5           34738       A    M1       CNG    60Nm@3500rpm  ...
#
# ...

# %%
df.shape
# Out:
# (43944, 41)

# %%
for c in df.columns:
    if df[c].dtype=='O':
        print(c)
# Out:
# _id
# region_code
# segment
# model
# fuel_type
# max_torque
# max_power
# engine_type
# is_esc
# is_adjustable_steering
# is_tpms
# is_parking_sensors
# is_parking_camera
# rear_brakes_type
# transmission_type
# steering_type
# is_front_fog_lights
# is_rear_window_wiper
# is_rear_window_washer
# is_rear_window_defogger
# is_brake_assist
# is_power_door_locks
# is_central_locking
# is_power_steering
# is_driver_seat_height_adjustable
# is_day_night_rear_view_mirror
# is_ecw
# is_speed_alert

# %%
for n in df.columns:
    if df[n].dtype!="O":
        print(n)
# Out:
# subscription_length
# vehicle_age
# customer_age
# region_density
# airbags
# displacement
# cylinder
# turning_radius
# length
# width
# gross_weight
# ncap_rating
# claim_status
